# %%
## Get Plans and Calculate Pace to Plan

# %%
from pyspark.context import SparkContext
from pyspark.sql import HiveContext, SQLContext,SparkSession
from pyspark.sql import functions as F
from datetime import date,timedelta
from datetime import datetime
sc = SparkContext(appName = "Combined_Table")
sql_context = HiveContext(sc)
spark = SparkSession(sc)
spark = (SparkSession.builder.enableHiveSupport().getOrCreate())

# %%
spark 
import pandas as pd
import os
import numpy as np
import datetime
import time
import glob
import os
from numpy import nan
from pyspark.sql import functions as F
from pyspark.sql.functions import format_string

pd.set_option('display.width', 150)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#### RUN FUNCTIONS

## GROUP BY AM
exec("""def amgrp(work): 
    return work.groupby(by=['sbb_district','sbb_region_cc','record_date'],as_index=False).aggregate({
    'gnb_points_q1': 'sum',
    'gnb_points_q2': 'sum',
    'gnb_points_q3': 'sum',
    'gnb_points_q4': 'sum',
    'mur_q1': 'sum',
    'mur_q2': 'sum',
    'mur_q3': 'sum',
    'mur_q4': 'sum',
    'commref_q1': 'sum',
    'commref_q2': 'sum',
    'commref_q3': 'sum',
    'commref_q4': 'sum',
    'sbbcredit_q1': 'sum',
    'sbbcredit_q2': 'sum',
    'sbbcredit_q3': 'sum',
    'sbbcredit_q4': 'sum',
    'bcp_q1': 'sum',
    'bcp_q2': 'sum',
    'bcp_q3': 'sum',
    'bcp_q4': 'sum',
    'merchant_q1': 'sum',
    'merchant_q2': 'sum',
    'merchant_q3': 'sum',
    'merchant_q4': 'sum',
    'visa_q1': 'sum',
    'visa_q2': 'sum',
    'visa_q3': 'sum',
    'visa_q4': 'sum',
    'cms_q1': 'sum',
    'cms_q2': 'sum',
    'cms_q3': 'sum',
    'cms_q4': 'sum',
    'bbs_q1': 'sum',
    'bbs_q2': 'sum',
    'bbs_q3': 'sum',
    'bbs_q4': 'sum',
    'be_q1': 'sum',
    'be_q2': 'sum',
    'be_q3': 'sum',
    'be_q4': 'sum',
    'retailref_q1': 'sum',
    'retailref_q2': 'sum',
    'retailref_q3': 'sum',
    'retailref_q4': 'sum',
    'wealthref_q1': 'sum',
    'wealthref_q2': 'sum',
    'wealthref_q3': 'sum',
    'wealthref_q4': 'sum',
    'tds_fx_q1': 'sum',
    'tds_fx_q2': 'sum',
    'tds_fx_q3': 'sum',
    'tds_fx_q4': 'sum',
    'onetd_q1': 'sum',
    'onetd_q2': 'sum',
    'onetd_q3': 'sum',
    'onetd_q4': 'sum',
    'tdef_q1': 'sum',
    'tdef_q2': 'sum',
    'tdef_q3': 'sum',
    'tdef_q4': 'sum',
    'cli_q1': 'sum',
    'cli_q2': 'sum',
    'cli_q3': 'sum',
    'cli_q4': 'sum'  
    })""")

## GROUP BY SM
exec("""def smgrp(work): 
    return work.groupby(by=['sbb_region_cc','record_date'],as_index=False).aggregate({
    'gnb_points_q1': 'sum',
    'gnb_points_q2': 'sum',
    'gnb_points_q3': 'sum',
    'gnb_points_q4': 'sum',
    'mur_q1': 'sum',
    'mur_q2': 'sum',
    'mur_q3': 'sum',
    'mur_q4': 'sum',
    'commref_q1': 'sum',
    'commref_q2': 'sum',
    'commref_q3': 'sum',
    'commref_q4': 'sum',
    'sbbcredit_q1': 'sum',
    'sbbcredit_q2': 'sum',
    'sbbcredit_q3': 'sum',
    'sbbcredit_q4': 'sum',
    'bcp_q1': 'sum',
    'bcp_q2': 'sum',
    'bcp_q3': 'sum',
    'bcp_q4': 'sum',
    'merchant_q1': 'sum',
    'merchant_q2': 'sum',
    'merchant_q3': 'sum',
    'merchant_q4': 'sum',
    'visa_q1': 'sum',
    'visa_q2': 'sum',
    'visa_q3': 'sum',
    'visa_q4': 'sum',
    'cms_q1': 'sum',
    'cms_q2': 'sum',
    'cms_q3': 'sum',
    'cms_q4': 'sum',
    'bbs_q1': 'sum',
    'bbs_q2': 'sum',
    'bbs_q3': 'sum',
    'bbs_q4': 'sum',
    'be_q1': 'sum',
    'be_q2': 'sum',
    'be_q3': 'sum',
    'be_q4': 'sum',
    'retailref_q1': 'sum',
    'retailref_q2': 'sum',
    'retailref_q3': 'sum',
    'retailref_q4': 'sum',
    'wealthref_q1': 'sum',
    'wealthref_q2': 'sum',
    'wealthref_q3': 'sum',
    'wealthref_q4': 'sum',
    'tds_fx_q1': 'sum',
    'tds_fx_q2': 'sum',
    'tds_fx_q3': 'sum',
    'tds_fx_q4': 'sum',
    'onetd_q1': 'sum',
    'onetd_q2': 'sum',
    'onetd_q3': 'sum',
    'onetd_q4': 'sum',
    'tdef_q1': 'sum',
    'tdef_q2': 'sum',
    'tdef_q3': 'sum',
    'tdef_q4': 'sum',
    'cli_q1': 'sum',
    'cli_q2': 'sum',
    'cli_q3': 'sum',
    'cli_q4': 'sum' })""")

## GROUP BY NATIONAL OFFICE
exec("""def natgrp(work): 
    return work.groupby(by=['record_date'],as_index=False).aggregate({
    'gnb_points_q1': 'sum',
    'gnb_points_q2': 'sum',
    'gnb_points_q3': 'sum',
    'gnb_points_q4': 'sum',
    'mur_q1': 'sum',
    'mur_q2': 'sum',
    'mur_q3': 'sum',
    'mur_q4': 'sum',
    'commref_q1': 'sum',
    'commref_q2': 'sum',
    'commref_q3': 'sum',
    'commref_q4': 'sum',
    'sbbcredit_q1': 'sum',
    'sbbcredit_q2': 'sum',
    'sbbcredit_q3': 'sum',
    'sbbcredit_q4': 'sum',
    'bcp_q1': 'sum',
    'bcp_q2': 'sum',
    'bcp_q3': 'sum',
    'bcp_q4': 'sum',
    'merchant_q1': 'sum',
    'merchant_q2': 'sum',
    'merchant_q3': 'sum',
    'merchant_q4': 'sum',
    'visa_q1': 'sum',
    'visa_q2': 'sum',
    'visa_q3': 'sum',
    'visa_q4': 'sum',
    'cms_q1': 'sum',
    'cms_q2': 'sum',
    'cms_q3': 'sum',
    'cms_q4': 'sum',
    'bbs_q1': 'sum',
    'bbs_q2': 'sum',
    'bbs_q3': 'sum',
    'bbs_q4': 'sum',
    'be_q1': 'sum',
    'be_q2': 'sum',
    'be_q3': 'sum',
    'be_q4': 'sum',
    'retailref_q1': 'sum',
    'retailref_q2': 'sum',
    'retailref_q3': 'sum',
    'retailref_q4': 'sum',
    'wealthref_q1': 'sum',
    'wealthref_q2': 'sum',
    'wealthref_q3': 'sum',
    'wealthref_q4': 'sum',
    'tds_fx_q1': 'sum',
    'tds_fx_q2': 'sum',
    'tds_fx_q3': 'sum',
    'tds_fx_q4': 'sum',
    'onetd_q1': 'sum',
    'onetd_q2': 'sum',
    'onetd_q3': 'sum',
    'onetd_q4': 'sum',
    'tdef_q1': 'sum',
    'tdef_q2': 'sum',
    'tdef_q3': 'sum',
    'tdef_q4': 'sum',
    'cli_q1': 'sum',
    'cli_q2': 'sum',
    'cli_q3': 'sum',
    'cli_q4': 'sum' })""")

# %%
#################### GET ALL PLANS #######################
df_plans=spark.table("anp_cabbtdct1_working.SBB_FY_GOALS")
df_plan_filter=df_plans.toPandas()

df_plan_filter.columns=df_plan_filter.columns.str.lower()

cols = ['gnb_points_q1','gnb_points_q2','gnb_points_q3','gnb_points_q4','mur_q1','mur_q2','mur_q3','mur_q4','commref_q1',
        'commref_q2','commref_q3','commref_q4','sbbcredit_q1','sbbcredit_q2','sbbcredit_q3','sbbcredit_q4','bcp_q1','bcp_q2',
        'bcp_q3','bcp_q4','merchant_q1','merchant_q2','merchant_q3','merchant_q4','visa_q1','visa_q2','visa_q3',
        'visa_q4','cms_q1','cms_q2','cms_q3','cms_q4','bbs_q1','bbs_q2','bbs_q3','bbs_q4','be_q1','be_q2','be_q3','be_q4',
        'retailref_q1','retailref_q2','retailref_q3','retailref_q4','wealthref_q1','wealthref_q2','wealthref_q3','wealthref_q4',
        'tds_fx_q1','tds_fx_q2','tds_fx_q3','tds_fx_q4','onetd_q1','onetd_q2','onetd_q3','onetd_q4','tdef_q1','tdef_q2',
       'tdef_q3','tdef_q4','cli_q1','cli_q2','cli_q3','cli_q4']

df_plan_filter[cols] =df_plan_filter[cols].apply(pd.to_numeric, errors='coerce', axis=1)

## convert to float
#df_plan_filter = df_plan_filter.astype({'gnb_points_q1':float,
#                                        'gnb_points_q2':float,'gnb_points_q3':float,'gnb_points_q4':float,'mur_q1':float,'mur_q2':float,
#                                        'mur_q3':float,'mur_q4':float,'commref_q1':float,'commref_q2':float,'commref_q3':float,'commref_q4':float,'sbbcredit_q1':float,
#                                        'sbbcredit_q2':float,'sbbcredit_q3':float,'sbbcredit_q4':float,'bcp_q1':float,'bcp_q2':float,'bcp_q3':float,'bcp_q4':float,
#                                        'merchant_q1':float,'merchant_q2':float,'merchant_q3':float,'merchant_q4':float,'visa_q1':float,'visa_q2':float,'visa_q3':float,
#                                        'visa_q4':float,'cms_q1':float,'cms_q2':float,'cms_q3':float,'cms_q4':float,'bbs_q1':float,'bbs_q2':float,'bbs_q3':float,'bbs_q4':float,'be_q1':float,
#                                        'be_q2':float,'be_q3':float,'be_q4':float,'retailref_q1':float,'retailref_q2':float,'retailref_q3':float,'retailref_q4':float,
#                                        'wealthref_q1':float,'wealthref_q2':float,'wealthref_q3':float,'wealthref_q4':float,'tds_fx_q1':float,'tds_fx_q2':float,
#                                        'tds_fx_q3':float,'tds_fx_q4':float,'onetd_q1':float,'onetd_q2':float,'onetd_q3':float,'onetd_q4':float})

###########################################################################
#################### GET AMSB PLAN ########################################
df_plan_amsb=df_plan_filter[(df_plan_filter.level=='AMSB') & (df_plan_filter.fte=='1')]

############################################################################
################### GET AM and SM PLAN (SBB FILTER) ########################
df_plan_sbb_fil=df_plan_filter[(df_plan_filter.level=='AM_SM') & (df_plan_filter.fte=='1')]

###############################################################################
################### GET AM and SM PLAN (RETAIL FILTER) ########################
df_plan_retail_fil=df_plan_filter[(df_plan_filter.level=='AM_SM') & (df_plan_filter.fte=='Retail')]

##############################################################################
################### GET AM and SM PLAN (TOTAL FILTER) ########################
df_plan_total_fil=df_plan_filter[(df_plan_filter.level=='AM_SM')]

# %%
############### PROCESS AMSB ###################################

df_plan_amsb['scorecard_filter']='SBB'

## order the vars
amsb_plan_sbb_filter1=df_plan_amsb[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','gnb_points_q1',
                                        'gnb_points_q2','gnb_points_q3','gnb_points_q4','mur_q1','mur_q2',
                                        'mur_q3','mur_q4','commref_q1','commref_q2','commref_q3','commref_q4','sbbcredit_q1',
                                        'sbbcredit_q2','sbbcredit_q3','sbbcredit_q4','bcp_q1','bcp_q2','bcp_q3','bcp_q4',
                                        'merchant_q1','merchant_q2','merchant_q3','merchant_q4','visa_q1','visa_q2','visa_q3',
                                        'visa_q4','cms_q1','cms_q2','cms_q3','cms_q4','bbs_q1','bbs_q2','bbs_q3','bbs_q4','be_q1',
                                        'be_q2','be_q3','be_q4','retailref_q1','retailref_q2','retailref_q3','retailref_q4',
                                        'wealthref_q1','wealthref_q2','wealthref_q3','wealthref_q4','tds_fx_q1','tds_fx_q2',
                                        'tds_fx_q3','tds_fx_q4','onetd_q1','onetd_q2','onetd_q3','onetd_q4','tdef_q1','tdef_q2',
                                     'tdef_q3','tdef_q4','cli_q1','cli_q2','cli_q3','cli_q4']]

# %%
################################# sum up AM SBB FILTER #################################

##### sum up the AM SBB filter
am_plan_sbb_filter=amgrp(df_plan_sbb_fil)

## create 'level' and 'scorecard_filter' vars
am_plan_sbb_filter['level']='AM'
am_plan_sbb_filter['scorecard_filter']='SBB'
am_plan_sbb_filter['amsb_logon_id']=''

## order the vars
am_plan_sbb_filter1=am_plan_sbb_filter[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','gnb_points_q1',
                                        'gnb_points_q2','gnb_points_q3','gnb_points_q4','mur_q1','mur_q2',
                                        'mur_q3','mur_q4','commref_q1','commref_q2','commref_q3','commref_q4','sbbcredit_q1',
                                        'sbbcredit_q2','sbbcredit_q3','sbbcredit_q4','bcp_q1','bcp_q2','bcp_q3','bcp_q4',
                                        'merchant_q1','merchant_q2','merchant_q3','merchant_q4','visa_q1','visa_q2','visa_q3',
                                        'visa_q4','cms_q1','cms_q2','cms_q3','cms_q4','bbs_q1','bbs_q2','bbs_q3','bbs_q4','be_q1',
                                        'be_q2','be_q3','be_q4','retailref_q1','retailref_q2','retailref_q3','retailref_q4',
                                        'wealthref_q1','wealthref_q2','wealthref_q3','wealthref_q4','tds_fx_q1','tds_fx_q2',
                                        'tds_fx_q3','tds_fx_q4','onetd_q1','onetd_q2','onetd_q3','onetd_q4','tdef_q1','tdef_q2',
                                        'tdef_q3','tdef_q4','cli_q1','cli_q2','cli_q3','cli_q4']]

# %%
am_plan_sbb_filter1.head(5)

# %%
############### sum up SM SBB FILTER
sm_plan_sbb_filter=smgrp(df_plan_sbb_fil)

## create 'level' and 'scorecard_filter' vars
sm_plan_sbb_filter['level']='SM'
sm_plan_sbb_filter['scorecard_filter']='SBB'
sm_plan_sbb_filter['sbb_district']=''
sm_plan_sbb_filter['amsb_logon_id']=''

## order the vars
sm_plan_sbb_filter1=sm_plan_sbb_filter[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','gnb_points_q1',
                                        'gnb_points_q2','gnb_points_q3','gnb_points_q4','mur_q1','mur_q2',
                                        'mur_q3','mur_q4','commref_q1','commref_q2','commref_q3','commref_q4','sbbcredit_q1',
                                        'sbbcredit_q2','sbbcredit_q3','sbbcredit_q4','bcp_q1','bcp_q2','bcp_q3','bcp_q4',
                                        'merchant_q1','merchant_q2','merchant_q3','merchant_q4','visa_q1','visa_q2','visa_q3',
                                        'visa_q4','cms_q1','cms_q2','cms_q3','cms_q4','bbs_q1','bbs_q2','bbs_q3','bbs_q4','be_q1',
                                        'be_q2','be_q3','be_q4','retailref_q1','retailref_q2','retailref_q3','retailref_q4',
                                        'wealthref_q1','wealthref_q2','wealthref_q3','wealthref_q4','tds_fx_q1','tds_fx_q2',
                                        'tds_fx_q3','tds_fx_q4','onetd_q1','onetd_q2','onetd_q3','onetd_q4','tdef_q1','tdef_q2',
                                        'tdef_q3','tdef_q4','cli_q1','cli_q2','cli_q3','cli_q4']]

# %%
################################# RETAIL FILTER #################################

##### sum up the AM Retail filter
am_plan_ret_filter=amgrp(df_plan_retail_fil)

## create 'level' and 'scorecard_filter' vars
am_plan_ret_filter['level']='AM'
am_plan_ret_filter['scorecard_filter']='Retail'
am_plan_ret_filter['amsb_logon_id']=''

## order the vars
am_plan_ret_filter1=am_plan_ret_filter[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','gnb_points_q1',
                                        'gnb_points_q2','gnb_points_q3','gnb_points_q4','mur_q1','mur_q2',
                                        'mur_q3','mur_q4','commref_q1','commref_q2','commref_q3','commref_q4','sbbcredit_q1',
                                        'sbbcredit_q2','sbbcredit_q3','sbbcredit_q4','bcp_q1','bcp_q2','bcp_q3','bcp_q4',
                                        'merchant_q1','merchant_q2','merchant_q3','merchant_q4','visa_q1','visa_q2','visa_q3',
                                        'visa_q4','cms_q1','cms_q2','cms_q3','cms_q4','bbs_q1','bbs_q2','bbs_q3','bbs_q4','be_q1',
                                        'be_q2','be_q3','be_q4','retailref_q1','retailref_q2','retailref_q3','retailref_q4',
                                        'wealthref_q1','wealthref_q2','wealthref_q3','wealthref_q4','tds_fx_q1','tds_fx_q2',
                                        'tds_fx_q3','tds_fx_q4','onetd_q1','onetd_q2','onetd_q3','onetd_q4','tdef_q1','tdef_q2',
                                        'tdef_q3','tdef_q4','cli_q1','cli_q2','cli_q3','cli_q4']]

# %%
######### sum up the SM Retail filter
sm_plan_ret_filter=smgrp(df_plan_retail_fil)

## create 'level' and 'scorecard_filter' vars
sm_plan_ret_filter['level']='SM'
sm_plan_ret_filter['scorecard_filter']='Retail'
sm_plan_ret_filter['sbb_district']=''
sm_plan_ret_filter['amsb_logon_id']=''

## order the vars
sm_plan_ret_filter1=sm_plan_ret_filter[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','gnb_points_q1',
                                        'gnb_points_q2','gnb_points_q3','gnb_points_q4','mur_q1','mur_q2',
                                        'mur_q3','mur_q4','commref_q1','commref_q2','commref_q3','commref_q4','sbbcredit_q1',
                                        'sbbcredit_q2','sbbcredit_q3','sbbcredit_q4','bcp_q1','bcp_q2','bcp_q3','bcp_q4',
                                        'merchant_q1','merchant_q2','merchant_q3','merchant_q4','visa_q1','visa_q2','visa_q3',
                                        'visa_q4','cms_q1','cms_q2','cms_q3','cms_q4','bbs_q1','bbs_q2','bbs_q3','bbs_q4','be_q1',
                                        'be_q2','be_q3','be_q4','retailref_q1','retailref_q2','retailref_q3','retailref_q4',
                                        'wealthref_q1','wealthref_q2','wealthref_q3','wealthref_q4','tds_fx_q1','tds_fx_q2',
                                        'tds_fx_q3','tds_fx_q4','onetd_q1','onetd_q2','onetd_q3','onetd_q4','tdef_q1','tdef_q2',
                                        'tdef_q3','tdef_q4','cli_q1','cli_q2','cli_q3','cli_q4']]

# %%
################################# sum up TOTAL FILTER #################################

##### sum up the AM TOTAL filter
am_plan_tot_filter=amgrp(df_plan_total_fil)

## create 'level' and 'scorecard_filter' vars
am_plan_tot_filter['level']='AM'
am_plan_tot_filter['scorecard_filter']='Total'
am_plan_tot_filter['amsb_logon_id']=''

## order the vars
am_plan_tot_filter1=am_plan_tot_filter[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','gnb_points_q1',
                                        'gnb_points_q2','gnb_points_q3','gnb_points_q4','mur_q1','mur_q2',
                                        'mur_q3','mur_q4','commref_q1','commref_q2','commref_q3','commref_q4','sbbcredit_q1',
                                        'sbbcredit_q2','sbbcredit_q3','sbbcredit_q4','bcp_q1','bcp_q2','bcp_q3','bcp_q4',
                                        'merchant_q1','merchant_q2','merchant_q3','merchant_q4','visa_q1','visa_q2','visa_q3',
                                        'visa_q4','cms_q1','cms_q2','cms_q3','cms_q4','bbs_q1','bbs_q2','bbs_q3','bbs_q4','be_q1',
                                        'be_q2','be_q3','be_q4','retailref_q1','retailref_q2','retailref_q3','retailref_q4',
                                        'wealthref_q1','wealthref_q2','wealthref_q3','wealthref_q4','tds_fx_q1','tds_fx_q2',
                                        'tds_fx_q3','tds_fx_q4','onetd_q1','onetd_q2','onetd_q3','onetd_q4','tdef_q1','tdef_q2',
                                        'tdef_q3','tdef_q4','cli_q1','cli_q2','cli_q3','cli_q4']]

# %%
######### sum up the SM TOTAL filter
sm_plan_tot_filter=smgrp(df_plan_total_fil)

## create 'level' and 'scorecard_filter' vars
sm_plan_tot_filter['level']='SM'
sm_plan_tot_filter['scorecard_filter']='Total'
sm_plan_tot_filter['sbb_district']=''
sm_plan_tot_filter['amsb_logon_id']=''

## order the vars
sm_plan_tot_filter1=sm_plan_tot_filter[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','gnb_points_q1',
                                        'gnb_points_q2','gnb_points_q3','gnb_points_q4','mur_q1','mur_q2',
                                        'mur_q3','mur_q4','commref_q1','commref_q2','commref_q3','commref_q4','sbbcredit_q1',
                                        'sbbcredit_q2','sbbcredit_q3','sbbcredit_q4','bcp_q1','bcp_q2','bcp_q3','bcp_q4',
                                        'merchant_q1','merchant_q2','merchant_q3','merchant_q4','visa_q1','visa_q2','visa_q3',
                                        'visa_q4','cms_q1','cms_q2','cms_q3','cms_q4','bbs_q1','bbs_q2','bbs_q3','bbs_q4','be_q1',
                                        'be_q2','be_q3','be_q4','retailref_q1','retailref_q2','retailref_q3','retailref_q4',
                                        'wealthref_q1','wealthref_q2','wealthref_q3','wealthref_q4','tds_fx_q1','tds_fx_q2',
                                        'tds_fx_q3','tds_fx_q4','onetd_q1','onetd_q2','onetd_q3','onetd_q4','tdef_q1','tdef_q2',
                                        'tdef_q3','tdef_q4','cli_q1','cli_q2','cli_q3','cli_q4']]

# %%
######### sum up the NATIONAL OFFICE TOTAL filter
nat_plan_tot_filter=natgrp(sm_plan_tot_filter1)

## create 'level' and 'scorecard_filter' vars
nat_plan_tot_filter['level']='National Office'
nat_plan_tot_filter['scorecard_filter']='Total'
nat_plan_tot_filter['sbb_district']=''
nat_plan_tot_filter['sbb_region_cc']=''
nat_plan_tot_filter['amsb_logon_id']=''

## order the vars
nat_plan_tot_filter1=nat_plan_tot_filter[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','gnb_points_q1',
                                        'gnb_points_q2','gnb_points_q3','gnb_points_q4','mur_q1','mur_q2',
                                        'mur_q3','mur_q4','commref_q1','commref_q2','commref_q3','commref_q4','sbbcredit_q1',
                                        'sbbcredit_q2','sbbcredit_q3','sbbcredit_q4','bcp_q1','bcp_q2','bcp_q3','bcp_q4',
                                        'merchant_q1','merchant_q2','merchant_q3','merchant_q4','visa_q1','visa_q2','visa_q3',
                                        'visa_q4','cms_q1','cms_q2','cms_q3','cms_q4','bbs_q1','bbs_q2','bbs_q3','bbs_q4','be_q1',
                                        'be_q2','be_q3','be_q4','retailref_q1','retailref_q2','retailref_q3','retailref_q4',
                                        'wealthref_q1','wealthref_q2','wealthref_q3','wealthref_q4','tds_fx_q1','tds_fx_q2',
                                        'tds_fx_q3','tds_fx_q4','onetd_q1','onetd_q2','onetd_q3','onetd_q4','tdef_q1','tdef_q2',
                                        'tdef_q3','tdef_q4','cli_q1','cli_q2','cli_q3','cli_q4']]

# %%
################ CONCATENATE ALL DATAFRAMES
goals_all=pd.concat([amsb_plan_sbb_filter1,am_plan_sbb_filter1,sm_plan_sbb_filter1,am_plan_ret_filter1,sm_plan_ret_filter1,
                     am_plan_tot_filter1,sm_plan_tot_filter1,nat_plan_tot_filter1],axis=0)

# %%
## create "metric_name" for each metric category

## (1) TOTAL GNB POINTS
goals_gnb=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','gnb_points_q1',
                     'gnb_points_q2','gnb_points_q3','gnb_points_q4']]
goals_gnb['metric_name']='Total GNB Points'
##rename vars
goals_gnb.rename(columns = {'gnb_points_q1':'q1_plan', 'gnb_points_q2': 'q2_plan',
                       'gnb_points_q3':'q3_plan','gnb_points_q4': 'q4_plan'}, inplace = True)
##order vars
goals_gnb=goals_gnb[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]

## (2) MUR
goals_mur=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','mur_q1',
                     'mur_q2','mur_q3','mur_q4']]
goals_mur['metric_name']='Total MUR Mortgage Volume'
##rename vars
goals_mur.rename(columns = {'mur_q1':'q1_plan', 'mur_q2': 'q2_plan',
                       'mur_q3':'q3_plan','mur_q4': 'q4_plan'}, inplace = True)
##order vars
goals_mur=goals_mur[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]


## (3) COMMREF
goals_comm=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','commref_q1',
                     'commref_q2','commref_q3','commref_q4']]
goals_comm['metric_name']='ALL Total Commercial Volume'
##rename vars
goals_comm.rename(columns = {'commref_q1':'q1_plan', 'commref_q2': 'q2_plan',
                       'commref_q3':'q3_plan','commref_q4': 'q4_plan'}, inplace = True)
##order vars
goals_comm=goals_comm[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]


## (3) SBB CREDIT (GROSS VOLUME)
goals_gross=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','sbbcredit_q1',
                     'sbbcredit_q2','sbbcredit_q3','sbbcredit_q4']]
goals_gross['metric_name']='Total SBB Net Authorized Volume'
##rename vars
goals_gross.rename(columns = {'sbbcredit_q1':'q1_plan', 'sbbcredit_q2': 'q2_plan',
                       'sbbcredit_q3':'q3_plan','sbbcredit_q4': 'q4_plan'}, inplace = True)
##order vars
goals_gross=goals_gross[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]


## (4) BCP
goals_bcp=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','bcp_q1',
                     'bcp_q2','bcp_q3','bcp_q4']]
goals_bcp['metric_name']='Business Credit Protection(BCP) Widgets'
##rename vars
goals_bcp.rename(columns = {'bcp_q1':'q1_plan', 'bcp_q2': 'q2_plan',
                       'bcp_q3':'q3_plan','bcp_q4': 'q4_plan'}, inplace = True)
##order vars
goals_bcp=goals_bcp[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]


## (5) MERCHANT
goals_mer=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','merchant_q1',
                     'merchant_q2','merchant_q3','merchant_q4']]
goals_mer['metric_name']='Total Merchant Solutions'
##rename vars
goals_mer.rename(columns = {'merchant_q1':'q1_plan', 'merchant_q2': 'q2_plan',
                       'merchant_q3':'q3_plan','merchant_q4': 'q4_plan'}, inplace = True)
##order vars
goals_mer=goals_mer[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]


## (5) CREDIT CARDS (VISA)
goals_cc=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','visa_q1',
                     'visa_q2','visa_q3','visa_q4']]
goals_cc['metric_name']='Total Credit Cards'
##rename vars
goals_cc.rename(columns = {'visa_q1':'q1_plan', 'visa_q2': 'q2_plan',
                       'visa_q3':'q3_plan','visa_q4': 'q4_plan'}, inplace = True)
##order vars
goals_cc=goals_cc[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]


## (6) CMS
goals_cms=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','cms_q1',
                     'cms_q2','cms_q3','cms_q4']]
goals_cms['metric_name']='Total Cash Management Services (including RDC)'
##rename vars
goals_cms.rename(columns = {'cms_q1':'q1_plan', 'cms_q2': 'q2_plan',
                       'cms_q3':'q3_plan','cms_q4': 'q4_plan'}, inplace = True)
##order vars
goals_cms=goals_cms[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]


## (7) BBS
goals_bbs=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','bbs_q1',
                     'bbs_q2','bbs_q3','bbs_q4']]
goals_bbs['metric_name']='Referrals to BBS'
##rename vars
goals_bbs.rename(columns = {'bbs_q1':'q1_plan', 'bbs_q2': 'q2_plan',
                       'bbs_q3':'q3_plan','bbs_q4': 'q4_plan'}, inplace = True)
##order vars
goals_bbs=goals_bbs[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]


## (7) RETAIL REFERRALS
goals_retail=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','retailref_q1',
                     'retailref_q2','retailref_q3','retailref_q4']]
goals_retail['metric_name']='AMSB Retail Referrals'
##rename vars
goals_retail.rename(columns = {'retailref_q1':'q1_plan', 'retailref_q2': 'q2_plan',
                       'retailref_q3':'q3_plan','retailref_q4': 'q4_plan'}, inplace = True)
##order vars
goals_retail=goals_retail[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]


## (8) WEALTH REFERRALS
goals_wealth=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','wealthref_q1',
                     'wealthref_q2','wealthref_q3','wealthref_q4']]
goals_wealth['metric_name']='Total Wealth Referrals'
##rename vars
goals_wealth.rename(columns = {'wealthref_q1':'q1_plan', 'wealthref_q2': 'q2_plan',
                       'wealthref_q3':'q3_plan','wealthref_q4': 'q4_plan'}, inplace = True)
##order vars
goals_wealth=goals_wealth[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]


## (8) Total TD Securities Direct Trade
goals_tds=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','tds_fx_q1',
                     'tds_fx_q2','tds_fx_q3','tds_fx_q4']]
goals_tds['metric_name']='TD Securities Direct Trade'
##rename vars
goals_tds.rename(columns = {'tds_fx_q1':'q1_plan', 'tds_fx_q2': 'q2_plan',
                       'tds_fx_q3':'q3_plan','tds_fx_q4': 'q4_plan'}, inplace = True)
##order vars
goals_tds=goals_tds[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]


## (9) OneTD
goals_onetd=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','onetd_q1',
                     'onetd_q2','onetd_q3','onetd_q4']]
goals_onetd['metric_name']='Total OneTD Widgets'
##rename vars
goals_onetd.rename(columns = {'onetd_q1':'q1_plan', 'onetd_q2': 'q2_plan',
                       'onetd_q3':'q3_plan','onetd_q4': 'q4_plan'}, inplace = True)
##order vars
goals_onetd=goals_onetd[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]


## (9) TOTAL BUSINESS ESSENTIALS
goals_be=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','be_q1',
                     'be_q2','be_q3','be_q4']]
goals_be['metric_name']='Total Business Essentials Widgets'
##rename vars
goals_be.rename(columns = {'be_q1':'q1_plan', 'be_q2': 'q2_plan',
                       'be_q3':'q3_plan','be_q4': 'q4_plan'}, inplace = True)
##order vars
goals_be=goals_be[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]

## (10) TDEF ## Added for FY24

goals_tdef=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','tdef_q1',
                     'tdef_q2','tdef_q3','tdef_q4']]
goals_tdef['metric_name']='TDEF Volume'
##rename vars
goals_tdef.rename(columns = {'tdef_q1':'q1_plan', 'tdef_q2': 'q2_plan',
                       'tdef_q3':'q3_plan','tdef_q4': 'q4_plan'}, inplace = True)
##order vars
goals_tdef=goals_tdef[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]

## (11) BCC CLI ## Added for FY24

goals_cli=goals_all[['amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter','cli_q1',
                     'cli_q2','cli_q3','cli_q4']]
goals_cli['metric_name']='Credit Cards Increases'
##rename vars
goals_cli.rename(columns = {'cli_q1':'q1_plan', 'cli_q2': 'q2_plan',
                       'cli_q3':'q3_plan','cli_q4': 'q4_plan'}, inplace = True)
##order vars
goals_cli=goals_cli[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]

# %%
######## CREATE TOTAL BUSINESS BANKING REFERRAL VOLUME METRIC ###############
## pull out COMMREF and MUR
##convert to numeric first
    ## concatenate the two dataframes and sum
goals_bb=pd.concat([goals_comm,goals_mur],axis=0)
##change metric name
goals_bb['metric_name']='Total Business Banking Referral Volume'
## rename the vars
goals_bb.rename(columns = {'commref_q1':'q1_plan',
                             'mur_q1':'q1_plan',
                             'commref_q2': 'q2_plan',
                             'mur_q2':'q2_plan',
                             'commref_q3':'q3_plan',
                             'mur_q3':'q3_plan',
                             'commref_q4': 'q4_plan',
                             'mur_q4':'q4_plan'}, inplace = True)
## sum up
goals_bb1=goals_bb.groupby(by=['metric_name','level','amsb_logon_id','sbb_district','sbb_region_cc',
                        'record_date','scorecard_filter'],as_index=False).aggregate({
    'q1_plan': 'sum',
    'q2_plan': 'sum',
    'q3_plan': 'sum',
    'q4_plan': 'sum'})

##order vars
goals_bb2=goals_bb1[['metric_name','amsb_logon_id','sbb_district','sbb_region_cc','record_date','level','scorecard_filter',
                     'q1_plan','q2_plan','q3_plan','q4_plan']]

# %%
goals_bb2.head(10)

# %%
######## CONCATENATE THE DATAFRAMES
goals_all1=pd.concat([goals_gnb,goals_mur,goals_comm,goals_gross,goals_bcp,goals_mer,goals_cc,goals_cms,goals_bbs,goals_retail,
                     goals_wealth,goals_tds,goals_onetd, goals_be, goals_tdef,goals_cli,goals_bb2],axis=0)

# %%
goals_all1.metric_name.unique()

# %%
## Convert pandas dataframe to Pyspark dataframe and save in table
spark.sql("set hive.exec.dynamic.partition.mode=nonstrict")
spark.createDataFrame(goals_all1).write.mode("overwrite").format("hive").saveAsTable("anp_cabbtdct1_final.SBB_SC_OUTPUT_GOALS")

# %%
## END OF PROGRAM
